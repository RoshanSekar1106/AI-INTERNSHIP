# %% [markdown]
# <a href="https://colab.research.google.com/github/RoshanSekar1106/AI-INTERNSHIP/blob/main/computer_vision(image_processing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
cv2.__version__
# Out:
# '4.13.0'

# %%
img=cv2.imread('/content/sample_data/bmw.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=183x130>

# %%
#store img
cv2.imwrite('bmw .jpg',img)
# Out:
# True

# %%
print(img.size)
# Out:
# 71370

# %%
print(img.shape)
# Out:
# (130, 183, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
img=img[30:110,50:130]
img
# Out:
# array([[[ 96,  80,  73],
#         [122, 106, 100],
#         [ 18,   0,   0],
#         ...,
#         [ 29,  10,   2],
#         [ 17,   0,   1],
#         [ 12,   0,   3]],
#
#        [[123, 107, 101],
#         [119, 104, 101],
#         [ 33,  18,  16],
#         ...,
#         [ 22,   4,   0],
#         [ 22,   8,  10],
#         [ 18,   4,  10]],
#
#        [[109,  97,  91],
#         [ 73,  61,  57],
#         [ 44,  31,  29],
#         ...,
#         [ 26,  12,   6],
#         [ 10,   0,   0],
#         [  8,   0,   2]],
#
#        ...,
#
#        [[116,  96,  79],
#         [109,  91,  74],
#         [ 79,  62,  49],
#         ...,
#         [ 34,  15,  24],
#         [ 44,  19,  29],
#         [ 46,  19,  28]],
#
#        [[102,  82,  64],
#         [109,  91,  74],
#         [ 89,  72,  59],
#         ...,
#         [ 37,  17,  22],
#         [ 44,  23,  26],
#         [ 45,  24,  23]],
#
#        [[ 85,  65,  47],
#         [ 98,  80,  63],
#         [ 89,  70,  55],
# ...

# %%
img=cv2.flip(img,0)
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=80x80>

# %%
img=cv2.resize(img,(100,100))
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img0=cv2.blur(img,(5,5))
from google.colab.patches import cv2_imshow
cv2_imshow(img0)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>
